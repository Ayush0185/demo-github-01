# %% [markdown]
# #print functions

# %%
print('Machine learning')
# Out:
# Machine learning

# %%
print('Machin Learning'   +    'project')
# Out:
# Machin Learningproject

# %%
print(8)
# Out:
# 8

# %%
print(8+5)
# Out:
# 13

# %% [markdown]
# #basic data types:
#
# 1.   int
# 2.   float
# 3.   str

# %%
print(type(8))
# Out:
# int

# %%
type(5.3)
# Out:
# float

# %%
type("english")
# Out:
# str

# %% [markdown]
# #Constants & Variables

# %%
superhero = "Iron man"
print(superhero)
# Out:
# Iron man

# %%
marvel_super_hero = "captain america"
print(marvel_super_hero)
# Out:
# captain america

# %%
hero1,hero2,hero3 = "Iron man","captain america","bat man"
print(hero1)
print(hero2)
print(hero3)
# Out:
# Iron man
# captain america
# bat man

# %%
x = y = z =23
print(x)
print(y)
print(z)
# Out:
# 23
# 23
# 23

# %% [markdown]
# #Input Function

# %%
number_1 = int(input("Enter the first number : "))
number_2 = int(input("Enter the second number : "))

sum = number_1 + number_2
print(sum)
# Out:
# Enter the first number : 23
# Enter the second number : 24
# 47

# %%
# changing the data types in python:
num = 5
print(float(num))
# Out:
# 5.0
